# %% [markdown]
# # Minor project on Diabetes Dataset

# %%
import pandas as pd
import numpy as np

#1.Import dataset 
df=pd.read_csv("C:/Users/Guru/anaconda3/Diabetes.csv")

#3.a.Univariate
for name in df.columns:
    df.hist(column=name)

#3.b.bivariate 
i="Outcome"
for name in df.columns:
    df.plot.scatter(x=name,y=i)
    i=name
    

#2.Data quality check
df['Outcome']=df.Outcome.map({0:"No",1:"Yes"})
df=df.replace(0,np.nan)
df=df.sort_values(by="Age")
df.fillna(method="ffill",inplace=True)
df.dropna()
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 182          1.0    125.0           74.0           20.0     23.0  27.7
# 623          1.0     94.0           70.0           27.0    115.0  43.5
# 624          2.0    108.0           64.0           27.0    115.0  30.8
# 55           1.0     73.0           50.0           10.0    115.0  23.0
# 626          1.0    125.0           68.0           10.0    115.0  24.7
# ..           ...      ...            ...            ...      ...   ...
# 123          5.0    132.0           80.0           37.0    180.0  26.8
# 684          5.0    136.0           82.0           37.0    180.0  26.8
# 666          4.0    145.0           82.0           18.0    180.0  32.5
# 453          2.0    119.0           82.0           18.0    180.0  19.6
# 459          9.0    134.0           74.0           33.0     60.0  25.9
#
#      DiabetesPedigreeFunction  Age Outcome
# 182                     0.299   21      No
# ...

# %% [markdown]
# # #KNN Classification

# %%
from sklearn.model_selection import train_test_split
import numpy as np

#Import data
df=pd.read_csv("C:/Users/Guru/anaconda3/Diabetes.csv")

df['Outcome']=df.Outcome.map({0:"No",1:"Yes"})

#Extract 
X=df.drop("Outcome",axis=1)
y=df["Outcome"]

#Spliting data
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.3,random_state=42,stratify=y)

##Train the model
from sklearn.neighbors import KNeighborsClassifier
knn=KNeighborsClassifier(n_neighbors=25)
knn.fit(X_train,y_train)

#Test the model
knn.score(X_test,y_test)
 
#New data
new=pd.read_csv("C:/Users/Guru/anaconda3/newdata.csv")
knn.predict(new)
# Out:
# 0.7056277056277056

# %% [markdown]
# # #DecisionTree

# %%
import pandas as pd
from sklearn.model_selection import train_test_split

#Import data
df=pd.read_csv("C:/Users/Guru/anaconda3/Diabetes.csv")

#Extract
X=df.drop("Outcome",axis=1)
y=df["Outcome"]

#Spliting data

X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.3,stratify=y)

#train data
from sklearn.tree import DecisionTreeClassifier
model=DecisionTreeClassifier()
model.fit(X_train,y_train)

#Test the data
model.score(X_test,y_test)

#New data
new=pd.read_csv("C:/Users/Guru/anaconda3/newdata.csv")
knn.predict(new)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-408d0e53a083> in <module>
#      23 #New data
#      24 new=pd.read_csv("C:/Users/Guru/anaconda3/newdata.csv")
# ---> 25 knn.predict(new)
#
# NameError: name 'knn' is not defined
